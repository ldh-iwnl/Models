# %%
import pandas as pd
import numpy as np
df1 = pd.read_csv('flowdata.csv', index_col=0,parse_dates=True)
df1
# Out:
#                       L06_347  LS06_347  LS06_348
# Time
# 2009-01-01 00:00:00  0.137417  0.097500  0.016833
# 2009-01-01 03:00:00  0.131250  0.088833  0.016417
# 2009-01-01 06:00:00  0.113500  0.091250  0.016750
# 2009-01-01 09:00:00  0.135750  0.091500  0.016250
# 2009-01-01 12:00:00  0.140917  0.096167  0.017000
# ...                       ...       ...       ...
# 2013-01-01 12:00:00  1.710000  1.710000  0.129583
# 2013-01-01 15:00:00  1.420000  1.420000  0.096333
# 2013-01-01 18:00:00  1.178583  1.178583  0.083083
# 2013-01-01 21:00:00  0.898250  0.898250  0.077167
# 2013-01-02 00:00:00  0.860000  0.860000  0.075000
#
# [11697 rows x 3 columns]

# %%
df1[pd.Timestamp('2012-01-01 09:00'):pd.Timestamp('2012-01-01 19:00')] # Selecting a range of dates
# Out:
#                       L06_347  LS06_347  LS06_348
# Time
# 2012-01-01 09:00:00  0.330750  0.293583  0.029750
# 2012-01-01 12:00:00  0.295000  0.285167  0.031750
# 2012-01-01 15:00:00  0.301417  0.287750  0.031417
# 2012-01-01 18:00:00  0.322083  0.304167  0.038083

# %%
df1.tail(10)
# Out:
#                       L06_347  LS06_347  LS06_348
# Time
# 2012-12-31 21:00:00  0.846500  0.846500  0.170167
# 2013-01-01 00:00:00  1.688333  1.688333  0.207333
# 2013-01-01 03:00:00  2.693333  2.693333  0.201500
# 2013-01-01 06:00:00  2.220833  2.220833  0.166917
# 2013-01-01 09:00:00  2.055000  2.055000  0.175667
# 2013-01-01 12:00:00  1.710000  1.710000  0.129583
# 2013-01-01 15:00:00  1.420000  1.420000  0.096333
# 2013-01-01 18:00:00  1.178583  1.178583  0.083083
# 2013-01-01 21:00:00  0.898250  0.898250  0.077167
# 2013-01-02 00:00:00  0.860000  0.860000  0.075000

# %%
df1['2013']
# Out:
#                       L06_347  LS06_347  LS06_348
# Time
# 2013-01-01 00:00:00  1.688333  1.688333  0.207333
# 2013-01-01 03:00:00  2.693333  2.693333  0.201500
# 2013-01-01 06:00:00  2.220833  2.220833  0.166917
# 2013-01-01 09:00:00  2.055000  2.055000  0.175667
# 2013-01-01 12:00:00  1.710000  1.710000  0.129583
# 2013-01-01 15:00:00  1.420000  1.420000  0.096333
# 2013-01-01 18:00:00  1.178583  1.178583  0.083083
# 2013-01-01 21:00:00  0.898250  0.898250  0.077167
# 2013-01-02 00:00:00  0.860000  0.860000  0.075000

# %%
df1[df1.index.month == 1]
# Out:
#                       L06_347  LS06_347  LS06_348
# Time
# 2009-01-01 00:00:00  0.137417  0.097500  0.016833
# 2009-01-01 03:00:00  0.131250  0.088833  0.016417
# 2009-01-01 06:00:00  0.113500  0.091250  0.016750
# 2009-01-01 09:00:00  0.135750  0.091500  0.016250
# 2009-01-01 12:00:00  0.140917  0.096167  0.017000
# ...                       ...       ...       ...
# 2013-01-01 12:00:00  1.710000  1.710000  0.129583
# 2013-01-01 15:00:00  1.420000  1.420000  0.096333
# 2013-01-01 18:00:00  1.178583  1.178583  0.083083
# 2013-01-01 21:00:00  0.898250  0.898250  0.077167
# 2013-01-02 00:00:00  0.860000  0.860000  0.075000
#
# [1001 rows x 3 columns]

# %%
df1[(df1.index.hour>8) & (df1.index.hour<18)]
# Out:
#                       L06_347  LS06_347  LS06_348
# Time
# 2009-01-01 09:00:00  0.135750  0.091500  0.016250
# 2009-01-01 12:00:00  0.140917  0.096167  0.017000
# 2009-01-01 15:00:00  0.099167  0.091667  0.017583
# 2009-01-02 09:00:00  0.141917  0.097083  0.016417
# 2009-01-02 12:00:00  0.147833  0.101917  0.016417
# ...                       ...       ...       ...
# 2012-12-31 12:00:00  0.651250  0.651250  0.063833
# 2012-12-31 15:00:00  0.629000  0.629000  0.061833
# 2013-01-01 09:00:00  2.055000  2.055000  0.175667
# 2013-01-01 12:00:00  1.710000  1.710000  0.129583
# 2013-01-01 15:00:00  1.420000  1.420000  0.096333
#
# [4386 rows x 3 columns]

# %%
df1.between_time('9:00','17:00')
# Out:
#                       L06_347  LS06_347  LS06_348
# Time
# 2009-01-01 09:00:00  0.135750  0.091500  0.016250
# 2009-01-01 12:00:00  0.140917  0.096167  0.017000
# 2009-01-01 15:00:00  0.099167  0.091667  0.017583
# 2009-01-02 09:00:00  0.141917  0.097083  0.016417
# 2009-01-02 12:00:00  0.147833  0.101917  0.016417
# ...                       ...       ...       ...
# 2012-12-31 12:00:00  0.651250  0.651250  0.063833
# 2012-12-31 15:00:00  0.629000  0.629000  0.061833
# 2013-01-01 09:00:00  2.055000  2.055000  0.175667
# 2013-01-01 12:00:00  1.710000  1.710000  0.129583
# 2013-01-01 15:00:00  1.420000  1.420000  0.096333
#
# [4386 rows x 3 columns]

# %%
df1.resample('D').mean().head() # Resampling to daily data and taking the mean
# Out:
#              L06_347  LS06_347  LS06_348
# Time
# 2009-01-01  0.125010  0.092281  0.016635
# 2009-01-02  0.124146  0.095781  0.016406
# 2009-01-03  0.113562  0.085542  0.016094
# 2009-01-04  0.140198  0.102708  0.017323
# 2009-01-05  0.128812  0.104490  0.018167
